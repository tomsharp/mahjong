# %%
import numpy as np
import random

# %%
def create_tiles():
    # create tiles

    # regular tiles
    tiles = []
    for i in range(1,10):
        for j in ['C', 'N', 'B']:
            tiles.append((j, i))   
    tiles = tiles*4

    # winds
    for i in range(1,5):
        for j in ['WN', 'WS', 'WE', 'WW', 'WG']:
            tiles.append((j, i)) 

    # sort
    tiles.sort()

    # @TODO - add more?
    
    return tiles

# %%
class Player:
    def __init__(self, Name):
        self.name = Name
        self.hand = []
        self.revealed = []
        self.trash = []

# %%
class Wall:
    def __init__(self, tiles):
        self.tiles = tiles

# %%
class MahJong:
    def __init__(self, player_names, tiles):
        
        print('MAHJONG - created by Tom Sharp')
        print('\n')
        assert len(player_names) == 4, 'Must have exactly four players'
        
        print('SETTING UP MAHJONG TABLE')
        # shuffle seating
        random.shuffle(player_names)
        self.players = [Player(name) for name in player_names]
        print('Seating Order:', [p.name for p in self.players])
        
        self.tiles = tiles
        print('Tiles:', tiles, '\n')
        
        self.game = None
        
        
    def create_game(self):
        self.game = self.Game()
        
        

    class Game:
        def __init__(self):
            print('CREATING GAME')
            print('Randomly shuffling tiles, building wall...')
            print('\n')
            [random.shuffle(mahjong.tiles) for i in range(1000)]
            self.wall = Wall(mahjong.tiles)
            self.players = mahjong.players
            self.pool = []

        def deal_tiles(self):
            print('DEALING TILES')
            print('Dealing tiles to each player, removing winds...')
            print('\n')
            # deal out tiles
            for k in range(0, 4):
                for i in range(0, 4):
                    j = (k*16) + (i*4)
                    tiles = self.wall.tiles[j:(j+4)]
                    self.players[i].hand.extend(tiles)

            # dealer gets extra piece
            self.players[0].hand.append(self.wall.tiles[64])

            # update wall 
            self.wall.tiles = self.wall.tiles[65:]


            # REPLACE WIND TILES
            while any(s.find('W')==0 for s in [tile[0] \
                      for player in mahjong.game.players for tile in player.hand]):
                for i in range(0,4):      

                    # throw out wind tiles
                    wind_indexes = [i for i, tile in enumerate(mahjong.game.players[i].hand) if tile[0].find('W') == 0]
                    for index in sorted(wind_indexes, reverse=True):
                        mahjong.game.players[i].trash.append(mahjong.game.players[i].hand[index])
                        del mahjong.game.players[i].hand[index]


                    if len(wind_indexes) >  0:
                        # draw new tiles
                        new_tiles = mahjong.game.wall.tiles[-len(wind_indexes):]
                        mahjong.game.players[i].hand.extend(new_tiles)

                        # update wall
                        mahjong.game.wall.tiles = mahjong.game.wall.tiles[:-len(wind_indexes)]
                    
            # sort every hand
            [player.hand.sort() for player in self.players]
            
        def reveal_joker(self):
            print('JOKER')
            self.joker = self.wall.tiles[-1]
            print(''' 
                 _____
                |  {}  |
                |     |
                |  {}  |
                |_____|'''.format(self.joker[0], self.joker[1]))
            
                    
        def throw(self):
            player = self.current_player 
            
            # print players hand
            for s in ['B', 'C', 'D']:
                print([tile for tile in player.hand if tile[0].find(s) != -1])
                
            # throw out tile
            r = input("Which tile to throw out?")

            # add to pool
            index = [i for i, tile in enumerate(player.hand) if tile[0]==r[0] and tile[1]==int(r[1])][0]
            self.pool.append(player.hand[index])

            # delete from hand
            del player.hand[index]
            
            print(''' 
                 _____
                |  {}  |
                |     |
                |  {}  |
                |_____|'''.format(r[0], r[1]))

            
        def start(self):
            print('STARTING GAME')
            print('Dealer ({}): Throw out first tile...'.format(self.players[0].name))
            self.current_player = self.players[0]
            self.throw()

# %%
mahjong = MahJong(player_names=['Tom', 'Helen', 'Hannah', 'Brenda'], tiles=create_tiles())
# Out:
# MAHJONG - created by Tom Sharp
#
#
# SETTING UP MAHJONG TABLE
# Seating Order: ['Hannah', 'Helen', 'Brenda', 'Tom']
# Tiles: [('B', 1), ('B', 1), ('B', 1), ('B', 1), ('B', 2), ('B', 2), ('B', 2), ('B', 2), ('B', 3), ('B', 3), ('B', 3), ('B', 3), ('B', 4), ('B', 4), ('B', 4), ('B', 4), ('B', 5), ('B', 5), ('B', 5), ('B', 5), ('B', 6), ('B', 6), ('B', 6), ('B', 6), ('B', 7), ('B', 7), ('B', 7), ('B', 7), ('B', 8), ('B', 8), ('B', 8), ('B', 8), ('B', 9), ('B', 9), ('B', 9), ('B', 9), ('C', 1), ('C', 1), ('C', 1), ('C', 1), ('C', 2), ('C', 2), ('C', 2), ('C', 2), ('C', 3), ('C', 3), ('C', 3), ('C', 3), ('C', 4), ('C', 4), ('C', 4), ('C', 4), ('C', 5), ('C', 5), ('C', 5), ('C', 5), ('C', 6), ('C', 6), ('C', 6), ('C', 6), ('C', 7), ('C', 7), ('C', 7), ('C', 7), ('C', 8), ('C', 8), ('C', 8), ('C', 8), ('C', 9), ('C', 9), ('C', 9), ('C', 9), ('N', 1), ('N', 1), ('N', 1), ('N', 1), ('N', 2), ('N', 2), ('N', 2), ('N', 2), ('N', 3), ('N', 3), ('N', 3), ('N', 3), ('N', 4), ('N', 4), ('N', 4), ('N', 4), ('N', 5), ('N', 5), ('N', 5), ('N', 5), ('N', 6), ('N', 6), ('N', 6), ('N', 6), ('N', 7), ('N', 7), ('N', 7), ('N', 7), ('N', 8), ('N', 8), ('N', 8), ('N', 8), ('N', 9), ('N', 9), ('N', 9), ('N', 9), ('WE', 1), ('WE', 2), ('WE', 3), ('WE', 4), ('WG', 1), ('WG', 2), ('WG', 3), ('WG', 4), ('WN', 1), ('WN', 2), ('WN', 3), ('WN', 4), ('WS', 1), ('WS', 2), ('WS', 3), ('WS', 4), ('WW', 1), ('WW', 2), ('WW', 3), ('WW', 4)]

# %%
mahjong.create_game()
# Out:
# CREATING GAME
# Randomly shuffling tiles, building wall...

# %%
mahjong.game.deal_tiles()
# Out:
# DEALING TILES
# Dealing tiles to each player, removing winds...

# %%
# mahjong.game.remove_winds()

# %%
for player in mahjong.game.players:
    player.hand.sort()
    print(len(player.trash))
    print('\n')
# Out:
# 4
#
#
# 2
#
#
# 1
#
#
# 4

# %%
len(mahjong.game.wall.tiles)
# Out:
# 52

# %%
# print(mahjong.game.wall.tiles)
# print('\n')

# # replace wind tiles
# while any(s.find('W')==0 for s in [tile[0] for player in mahjong.game.players for tile in player.hand]):
#     for i in range(0,4):      

#         # throw out wind tiles
#         wind_indexes = [i for i, tile in enumerate(mahjong.game.players[i].hand) if tile[0].find('W') == 0]
#         for index in sorted(wind_indexes, reverse=True):
#             mahjong.game.players[i].trash.append(mahjong.game.players[i].hand[index])
#             del mahjong.game.players[i].hand[index]


#         if len(wind_indexes) >  0:
#             # draw new tiles
#             new_tiles = mahjong.game.wall.tiles[-len(wind_indexes):]
#             mahjong.game.players[i].hand.extend(new_tiles)

#             # update wall
#             mahjong.game.wall.tiles = mahjong.game.wall.tiles[:-len(wind_indexes)]
#             print(mahjong.game.wall.tiles)
#             print('\n')
# Out:
# [('B', 8), ('N', 5), ('N', 1), ('C', 1), ('C', 6), ('N', 9), ('C', 2), ('B', 8), ('B', 9), ('C', 1), ('N', 9), ('N', 9), ('B', 7), ('WN', 3), ('N', 8), ('C', 4), ('B', 1), ('C', 9), ('B', 2), ('N', 6), ('N', 1), ('B', 1), ('B', 2), ('N', 2), ('C', 1), ('C', 6), ('B', 3), ('N', 4), ('N', 6), ('C', 3), ('N', 2), ('C', 1), ('B', 4), ('C', 2), ('C', 9), ('N', 2), ('WS', 4), ('WG', 1), ('C', 3), ('C', 3), ('N', 9), ('B', 3), ('N', 4), ('C', 2), ('C', 6), ('C', 5)]

# %%
print(len(mahjong.game.wall.tiles))
# Out:
# 46

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
mahjong.game.remove_winds()

# %%
mahjong.game.reveal_joker()

# %%
mahjong.game.start()
