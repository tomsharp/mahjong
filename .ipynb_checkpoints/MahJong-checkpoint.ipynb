# %%
import numpy as np
import random

# %%
def create_tiles():
    # create tiles

    # regular tiles
    tiles = []
    for i in range(1,10):
        for j in ['C', 'D', 'B']:
            tiles.append((j, i))   
    tiles = tiles*4

    # winds
    for i in range(1,5):
        for j in ['WN', 'WS', 'WE', 'WW', 'WG']:
            tiles.append((j, i)) 

    # sort
    tiles.sort()

    # @TODO - add more?
    
    return tiles

# %%
class Player:
    def __init__(self, Name):
        self.name = Name
        self.hand = []
        self.revealed = []
        self.trash = []

# %%
class Wall:
    def __init__(self, tiles):
        self.tiles = tiles

# %%
class MahJong:
    
    def __init__(self, names):
        assert len(names) == 4, 'Must have exactly four players'
        random.shuffle(names)
        self.players = [Player(name) for name in names]
        self.wall = Wall(create_tiles())
        print('Seating Order:', [p.name for p in self.players])

    def start_game(self):
        [random.shuffle(self.wall.tiles) for i in range(1000)]
        
        # deal out tiles
        for k in range(0, 4):
            for i in range(0, 4):
                j = (k*16) + (i*4)
                tiles = self.wall.tiles[j:(j+4)]
                self.players[i].hand.extend(tiles)
                
        # dealer gets extra piece
        self.players[0].hand.append(self.wall.tiles[64])
        
        # remove tiles from wall 
        self.wall.tiles = self.wall.tiles[65:]
        
        # replace wind tiles
        while any(s.find('W')==0 for s in [tile[0] for player in self.players for tile in player.hand]):
            for i in range(0,4):      

                # throw out wind tiles
                wind_indexes = [i for i, tile in enumerate(self.players[i].hand) if tile[0].find('W') == 0]
                for index in sorted(wind_indexes, reverse=True):
                    self.players[i].trash.append(self.players[i].hand[index])
                    del self.players[i].hand[index]

                # draw new tiles
                new_tiles = self.wall.tiles[:len(wind_indexes)]
                self.players[i].hand.extend(new_tiles)

# %%
mahjong = MahJong(['Tom', 'Helen', 'Hannah', 'Brenda'])
mahjong.start_game()
for i in range(0,4):
    print(mahjong.players[i].hand, '\n', len(mahjong.players[i].hand), '\n',  mahjong.players[i].trash, '\n', '\n', )
# Out:
# Seating Order: ['Hannah', 'Helen', 'Tom', 'Brenda']

# %%
for i in range(1,4):

    print('''
             _____
            |  {}  |
            |     |
            |  {}  |
            |_____|

            '''.format('B', i))
# Out:
#              _____
#             |  B  |
#             |     |
#             |  1  |
#             |_____|
#
#
#
#              _____
#             |  B  |
#             |     |
#             |  2  |
#             |_____|
#
#
#
#              _____
#             |  B  |
#             |     |
#             |  3  |
#             |_____|
